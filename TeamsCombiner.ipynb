# %%
import pandas as pd
import ujson

# %%
records = map(ujson.loads, open('swiss.ndjson',encoding='utf-8'))
df1 = pd.DataFrame.from_records(records)
df1.head()
# Out:
#               id       username  online  \
# 0     vay_vision     Vay_Vision   False
# 1   ian_fidelino   Ian_fidelino   False
# 2  bltsandwich64  bltsandwich64   False
# 3      rchoi2010      rchoi2010   False
# 4     furyempire     FuryEmpire   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 2087, 'rating': 1785, 'rd'...  1588244909571
# 1  {'blitz': {'games': 1282, 'rating': 2297, 'rd'...  1589001550345
# 2  {'blitz': {'games': 92, 'rating': 1439, 'rd': ...  1596664263279
# 3  {'blitz': {'games': 2, 'rating': 1145, 'rd': 2...  1616966305205
# 4  {'puzzle': {'games': 49, 'rating': 1425, 'rd':...  1614890838673
#
#           seenAt                        playTime language  \
# 0  1616980179204     {'total': 908091, 'tv': 83}    en-US
# 1  1616973550553  {'total': 1814631, 'tv': 4893}    en-US
# 2  1616970528359   {'total': 146022, 'tv': 1102}    en-US
# 3  1616972037806        {'total': 2319, 'tv': 0}    en-US
# ...

# %%
records = map(ujson.loads, open('fide.ndjson',encoding='utf-8'))
df2 = pd.DataFrame.from_records(records)
df2.head()
# Out:
#               id       username  online  \
# 0      fatemeh82      FATEMEH82   False
# 1  henriquemuniz  Henriquemuniz   False
# 2       dgearh10       Dgearh10   False
# 3     knowledgez     knowledgez   False
# 4         kszela         Kszela   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 158, 'rating': 1183, 'rd':...  1615358636824
# 1  {'blitz': {'games': 418, 'rating': 1639, 'rd':...  1564592891658
# 2  {'chess960': {'games': 6, 'rating': 1715, 'rd'...  1598743653972
# 3  {'blitz': {'games': 2, 'rating': 1775, 'rd': 2...  1616605815347
# 4  {'blitz': {'games': 11, 'rating': 1271, 'rd': ...  1616945778034
#
#           seenAt                     playTime language  \
# 0  1616972575577    {'total': 64223, 'tv': 0}    fa-IR
# 1  1616977523464  {'total': 579902, 'tv': 17}    pt-BR
# 2  1616970471836   {'total': 404575, 'tv': 0}    en-US
# 3  1616967780586    {'total': 17634, 'tv': 0}    en-US
# ...

# %%
records = map(ujson.loads, open('crest.ndjson',encoding='utf-8'))
df3 = pd.DataFrame.from_records(records)
df3.head()
# Out:
#                  id          username  online  \
# 0        maks-andr8        MAKS-Andr8   False
# 1     jamilchess222     Jamilchess222   False
# 2         almir1973         Almir1973   False
# 3  krschess_youtube  Krschess_youtube   False
# 4      bkd_deatheye      BKD_DeathEye   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 6, 'rating': 1384, 'rd'...  1585151745754
# 1  {'blitz': {'games': 9, 'rating': 1657, 'rd': 1...  1615104451901
# 2  {'blitz': {'games': 946, 'rating': 2102, 'rd':...  1605883726198
# 3  {'chess960': {'games': 179, 'rating': 1956, 'r...  1611246312488
# 4  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1616951874245
#
#                                              profile         seenAt  \
# 0  {'country': 'UA', 'location': 'Винница', 'firs...  1616958523337
# 1  {'country': 'AZ', 'location': 'Baku', 'bio': '...  1616965222641
# ...

# %%
records = map(ujson.loads, open('zhig.ndjson',encoding='utf-8'))
df4 = pd.DataFrame.from_records(records)
df4.head()
# Out:
#                    id            username  online  \
# 0         muduran2007         muduran2007   False
# 1            kikes123            kikes123   False
# 2           dayre0803           Dayre0803   False
# 3  el_ajedresista_123  el_ajedresista_123   False
# 4         avegners587         Avegners587   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 1, 'rating': 1652, 'rd'...  1531765141338
# 1  {'blitz': {'games': 10, 'rating': 1792, 'rd': ...  1615479326077
# 2  {'chess960': {'games': 1, 'rating': 1398, 'rd'...  1607091347929
# 3  {'antichess': {'games': 5, 'rating': 1568, 'rd...  1616875727683
# 4  {'chess960': {'games': 6, 'rating': 1501, 'rd'...  1613823414832
#
#                                              profile         seenAt  \
# 0                                  {'country': 'TR'}  1616968717731
# 1                                                NaN  1616966135574
# ...

# %%
records = map(ujson.loads, open('agad.ndjson',encoding='utf-8'))
df5 = pd.DataFrame.from_records(records)
df5.head()
# Out:
#                id        username  online  \
# 0      pl_premium      pl_premium   False
# 1     santhosh600     Santhosh600   False
# 2         night34         night34   False
# 3       shafiq777       Shafiq777   False
# 4  avamtheamazing  AvamtheAmazing    True
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 18, 'rating': 1300, 'rd': ...  1484523927267
# 1  {'chess960': {'games': 9, 'rating': 1423, 'rd'...  1607983213536
# 2  {'chess960': {'games': 2, 'rating': 1360, 'rd'...  1615166747294
# 3  {'blitz': {'games': 154, 'rating': 1399, 'rd':...  1527947780403
# 4  {'chess960': {'games': 3, 'rating': 1426, 'rd'...  1591392096588
#
#           seenAt                      playTime language  \
# 0  1616978160451    {'total': 119892, 'tv': 0}    en-GB
# 1  1616982635168  {'total': 100059, 'tv': 727}    en-US
# 2  1616976380982    {'total': 8466, 'tv': 337}    en-US
# 3  1616976999618  {'total': 763574, 'tv': 178}    en-GB
# ...

# %%
records = map(ujson.loads, open('pawn.ndjson',encoding='utf-8'))
df6 = pd.DataFrame.from_records(records)
df6.head()
# Out:
#                 id         username  online  \
# 0  ajedrezalmaximo  AjedrezAlMaximo   False
# 1      j2001213900      J2001213900   False
# 2          foxdeed          foxdeed   False
# 3          ulyanka          Ulyanka   False
# 4   barabashovo-11   BARABASHOVO-11   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1616983910563
# 1  {'chess960': {'games': 1, 'rating': 1258, 'rd'...  1608799419535
# 2  {'chess960': {'games': 15, 'rating': 1764, 'rd...  1595156925234
# 3  {'chess960': {'games': 14, 'rating': 1617, 'rd...  1574784565372
# 4  {'chess960': {'games': 6, 'rating': 1771, 'rd'...  1611693363814
#
#                                              profile         seenAt  \
# 0  {'country': 'MX', 'bio': 'Cuenta oficial del C...  1616984589837
# 1  {'country': 'JO', 'location': 'قصبة عمان', 'bi...  1616961143816
# 2                                  {'country': 'EG'}  1616976146178
# ...

# %%
records = map(ujson.loads, open('satr.ndjson',encoding='utf-8'))
df7 = pd.DataFrame.from_records(records)
df7.head()
# Out:
#                id        username  online  \
# 0    chesskasprof    chesskasprof   False
# 1       umutmert1       UmutMert1   False
# 2  cemderinay3000  CemDerinay3000   False
# 3       karansarp       KaranSarp   False
# 4        ozancemm        Ozancemm   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 1, 'rating': 1314, 'rd'...  1605093577947
# 1  {'chess960': {'games': 6, 'rating': 1109, 'rd'...  1584387339542
# 2  {'chess960': {'games': 1, 'rating': 1275, 'rd'...  1613718297309
# 3  {'blitz': {'games': 127, 'rating': 1445, 'rd':...  1535913244553
# 4  {'antichess': {'games': 4, 'rating': 1298, 'rd...  1553872865707
#
#                                              profile         seenAt  \
# 0  {'country': 'EG', 'location': 'دمياط', 'bio': ...  1616962818414
# 1  {'country': 'TR', 'location': 'Bandırma', 'bio...  1616955749732
# 2      {'country': 'TR', 'firstName': 'Cem Derinay'}  1616955244646
# ...

# %%
records = map(ujson.loads, open('strong.ndjson',encoding='utf-8'))
df8 = pd.DataFrame.from_records(records)
df8.head()
# Out:
#              id      username  online  \
# 0  rasulovvugar  rasulovvugar    True
# 1   forkyknight   Forkyknight    True
# 2     botfranek     BotFranek    True
# 3    jacobshout    JacobShout   False
# 4  serra_durgun  Serra_Durgun   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 272, 'rating': 2181, 'r...  1549826544459
# 1  {'chess960': {'games': 15, 'rating': 1595, 'rd...  1558075120052
# 2  {'blitz': {'games': 266, 'rating': 1971, 'rd':...  1543095690060
# 3  {'chess960': {'games': 4, 'rating': 743, 'rd':...  1615623962720
# 4  {'chess960': {'games': 2, 'rating': 1271, 'rd'...  1600953701003
#
#                                              profile         seenAt  \
# 0  {'country': 'AZ', 'location': 'Ganja city', 'f...  1617027134867
# 1  {'country': 'IN', 'location': 'faridabad', 'bi...  1617026699423
# 2                                  {'country': 'PL'}  1617027047022
# ...

# %%
records = map(ujson.loads, open('bengal.ndjson',encoding='utf-8'))
df9 = pd.DataFrame.from_records(records)
df9.head()
# Out:
#                     id             username  online  \
# 0  blunderrific_player  blunderrific_player    True
# 1    rodolfo_sarmiento    Rodolfo_Sarmiento    True
# 2       varisman_b2004       Varisman_B2004    True
# 3          singajehuda          SingaJehuda   False
# 4              arushyt              ArushYT   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 2, 'rating': 1842, 'rd': 2...  1616983849211
# 1  {'chess960': {'games': 36, 'rating': 1630, 'rd...  1596682474990
# 2  {'blitz': {'games': 945, 'rating': 1070, 'rd':...  1585186061040
# 3  {'chess960': {'games': 13, 'rating': 1952, 'rd...  1616928736625
# 4  {'chess960': {'games': 1, 'rating': 1718, 'rd'...  1615028835956
#
#           seenAt                    playTime language  \
# 0  1616984758177     {'total': 335, 'tv': 0}    en-US
# 1  1616984881501  {'total': 180365, 'tv': 0}    en-US
# 2  1616985233497  {'total': 358578, 'tv': 0}    en-US
# ...

# %%
records = map(ujson.loads, open('eric.ndjson',encoding='utf-8'))
df10 = pd.DataFrame.from_records(records)
df10.head()
# Out:
#                  id          username  online  \
# 0  kevinkochmeister  kevinkochmeister    True
# 1           chrsdgh           chrsdgh   False
# 2      pietroand007      Pietroand007   False
# 3     jeromenumber1     JeromeNumber1   False
# 4       iospatharis       IoSpatharis   False
#
#                                                perfs      createdAt  \
# 0  {'antichess': {'games': 11, 'rating': 1290, 'r...  1591265415434
# 1  {'blitz': {'games': 49, 'rating': 1255, 'rd': ...  1608221746508
# 2  {'chess960': {'games': 25, 'rating': 1247, 'rd...  1591790224374
# 3  {'blitz': {'games': 138, 'rating': 1020, 'rd':...  1592756221837
# 4  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1615489170780
#
#           seenAt                       playTime language  \
# 0  1617027574594     {'total': 288885, 'tv': 0}    de-DE
# 1  1617022353762     {'total': 140636, 'tv': 0}    en-US
# 2  1617024216864  {'total': 444423, 'tv': 1158}    it-IT
# ...

# %%
records = map(ujson.loads, open('turk.ndjson',encoding='utf-8'))
df11 = pd.DataFrame.from_records(records)
df11.head()
# Out:
#                    id            username  online  \
# 0             cinar-t             CiNar-T   False
# 1             barbarr             barbarr   False
# 2  speedrun2000olalim  speedrun2000olalim   False
# 3       kamilkamilovs       kamilkamilovs   False
# 4            bestnick            BestnicK   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 1, 'rating': 1397, 'rd'...  1603543975642
# 1  {'chess960': {'games': 131, 'rating': 1860, 'r...  1512063617720
# 2  {'puzzle': {'games': 4, 'rating': 1906, 'rd': ...  1616997880250
# 3  {'blitz': {'games': 465, 'rating': 819, 'rd': ...  1614641376374
# 4  {'blitz': {'games': 5, 'rating': 1442, 'rd': 1...  1606530972931
#
#                                              profile         seenAt  \
# 0  {'country': 'TR', 'location': 'Çekmeköy-Taşdel...  1617013931993
# 1                                                NaN  1617003882019
# ...

# %%
records = map(ujson.loads, open('netw.ndjson',encoding='utf-8'))
df12 = pd.DataFrame.from_records(records)
df12.head()
# Out:
#                     id             username  online  \
# 0           arvischess           arvischess    True
# 1              areessa              areessa   False
# 2              moirkum              Moirkum   False
# 3      wissem_saadaoui      Wissem_Saadaoui   False
# 4  priyansubahalia_123  PriyansuBahalia_123   False
#
#                                                perfs      createdAt  \
# 0  {'chess960': {'games': 1, 'rating': 1905, 'rd'...  1452465145423
# 1  {'chess960': {'games': 1, 'rating': 1375, 'rd'...  1606304599763
# 2  {'chess960': {'games': 1, 'rating': 2200, 'rd'...  1597340837401
# 3  {'blitz': {'games': 5, 'rating': 942, 'rd': 15...  1612567187134
# 4  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1612034979825
#
#                                              profile         seenAt  \
# 0  {'country': 'LT', 'location': 'Kaunas', 'first...  1617028430000
# 1  {'country': 'MY', 'location': 'elmina', 'bio':...  1617027054851
# ...

# %%
records = map(ujson.loads, open('levi.ndjson',encoding='utf-8'))
df13 = pd.DataFrame.from_records(records)
df13.head()
# Out:
#                id        username  online  \
# 0      kirill3000      kiRilL3000    True
# 1          zlook1          zLooK1    True
# 2  duruyeniyurt2b  duruyeniyurt2b   False
# 3     iospatharis     IoSpatharis   False
# 4      lexavoksal      lexavoksal   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 160, 'rating': 2047, 'rd':...  1552034449675
# 1  {'blitz': {'games': 69, 'rating': 2151, 'rd': ...  1609664909226
# 2  {'chess960': {'games': 1, 'rating': 1318, 'rd'...  1600166772546
# 3  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1615489170780
# 4  {'blitz': {'games': 1762, 'rating': 1843, 'rd'...  1582572622991
#
#                                              profile         seenAt  \
# 0  {'country': 'UA', 'links': 'er/kirill200706www...  1617030425097
# 1  {'country': 'RU', 'location': 'InGar', 'bio': ...  1617030218396
# 2  {'country': '_lichess', 'location': 'ANKARA', ...  1617022745954
# ...

# %%
records = map(ujson.loads, open('mast.ndjson',encoding='utf-8'))
df14 = pd.DataFrame.from_records(records)
df14.head()
# Out:
#                     id             username  online  \
# 0  pineapplesomething2  pineapplesomething2    True
# 1            am_better            am_better   False
# 2             amridz10             amridz10   False
# 3       boguslawarutek       Boguslawarutek    True
# 4        ojnebbenjo000        OjnebBenjo000   False
#
#                                                perfs      createdAt  \
# 0  {'puzzle': {'games': 4355, 'rating': 2264, 'rd...  1605045791913
# 1  {'blitz': {'games': 1, 'rating': 1669, 'rd': 3...  1616930536299
# 2  {'blitz': {'games': 287, 'rating': 1751, 'rd':...  1596295054711
# 3  {'chess960': {'games': 2, 'rating': 1159, 'rd'...  1616499735244
# 4  {'blitz': {'games': 1, 'rating': 1469, 'rd': 4...  1616905796170
#
#                                              profile         seenAt  \
# 0      {'country': '_pirate', 'location': 'WCI 🥱🎂😋'}  1617029553300
# 1                                                NaN  1617005402442
# ...

# %%
records = map(ujson.loads, open('talk.ndjson',encoding='utf-8'))
df15 = pd.DataFrame.from_records(records)
df15.head()
# Out:
#                     id             username  online  \
# 0           rowan8_0-0           Rowan8_0-0   False
# 1         thepawn_star         ThePawn_Star    True
# 2  khenterdyldaling014  KhentErdyldaling014   False
# 3            kkkuyyuuu            Kkkuyyuuu   False
# 4             sanj2013             sanj2013   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 71, 'rating': 1035, 'rd': ...  1612425669807
# 1  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1617018425719
# 2  {'chess960': {'games': 3, 'rating': 1684, 'rd'...  1611877148964
# 3  {'blitz': {'games': 17, 'rating': 1571, 'rd': ...  1616235891589
# 4  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1616746308711
#
#           seenAt                   playTime language  \
# 0  1617021851920  {'total': 20165, 'tv': 0}    en-GB
# 1  1617027675223     {'total': 41, 'tv': 0}    en-US
# 2  1617023608016  {'total': 23810, 'tv': 0}    en-US
# ...

# %%
records = map(ujson.loads, open('andh.ndjson',encoding='utf-8'))
df16 = pd.DataFrame.from_records(records)
df16.head()
# Out:
#              id      username  online  \
# 0  rondomikko13  RondoMikko13   False
# 1  strangestone  Strangestone   False
# 2       sapno12       Sapno12   False
# 3   shourya5890   Shourya5890   False
# 4  realchess_td  Realchess_TD   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 62, 'rating': 2228, 'rd': ...  1612371546829
# 1  {'blitz': {'games': 138, 'rating': 1748, 'rd':...  1613236925530
# 2  {'blitz': {'games': 10, 'rating': 1164, 'rd': ...  1614181010806
# 3  {'blitz': {'games': 10, 'rating': 1703, 'rd': ...  1616426433999
# 4  {'blitz': {'games': 127, 'rating': 2521, 'rd':...  1594659746455
#
#                                              profile         seenAt  \
# 0        {'firstName': 'Rondo', 'lastName': 'Mikko'}  1617027479486
# 1                                                NaN  1617006092002
# 2                                                NaN  1617001852453
# ...

# %%
records = map(ujson.loads, open('russ.ndjson',encoding='utf-8'))
df17 = pd.DataFrame.from_records(records)
df17.head()
# Out:
#            id    username  online  \
# 0     sg20068     SG20068   False
# 1       shpet       shpet    True
# 2     myn2020     myn2020   False
# 3     gusrang     gusrang   False
# 4  giordanvic  GiordanVic   False
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 17, 'rating': 2005, 'rd': ...  1616273509915
# 1  {'blitz': {'games': 283, 'rating': 1329, 'rd':...  1585816104345
# 2  {'puzzle': {'games': 97, 'rating': 1410, 'rd':...  1584711077590
# 3  {'blitz': {'games': 2948, 'rating': 2048, 'rd'...  1603778931165
# 4  {'chess960': {'games': 2, 'rating': 1721, 'rd'...  1462899763593
#
#          seenAt                     playTime language  \
# 0  1.617023e+12    {'total': 10603, 'tv': 0}    es-ES
# 1  1.617031e+12   {'total': 257988, 'tv': 0}    ru-RU
# 2  1.617024e+12   {'total': 196492, 'tv': 0}    ru-RU
# 3  1.617013e+12  {'total': 1804647, 'tv': 0}    es-ES
# 4  1.616966e+12   {'total': 556012, 'tv': 0}    it-IT
#
# ...

# %%
records = map(ujson.loads, open('land.ndjson',encoding='utf-8'))
df18 = pd.DataFrame.from_records(records)
df18.head()
# Out:
#                    id            username  online  \
# 0  albert_einstein_an  Albert_Einstein_AN    True
# 1            ozzy2013            Ozzy2013   False
# 2       maksonych1983       Maksonych1983   False
# 3           yhlas8555           yhlas8555   False
# 4          zasdfghjkl          zasdfghjkl    True
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 515, 'rating': 1629, 'rd':...  1561506360228
# 1  {'puzzle': {'games': 239, 'rating': 1611, 'rd'...  1607152893042
# 2  {'blitz': {'games': 2018, 'rating': 1897, 'rd'...  1514794856388
# 3  {'blitz': {'games': 4, 'rating': 1864, 'rd': 1...  1617022848025
# 4  {'blitz': {'games': 49, 'rating': 1616, 'rd': ...  1614658565745
#
#                                              profile         seenAt  \
# 0  {'country': 'BR', 'location': 'Barbalha', 'bio...  1617030803893
# 1  {'country': 'AZ', 'location': 'Baku', 'bio': '...  1617030770844
# ...

# %%
records = map(ujson.loads, open('iran.ndjson',encoding='utf-8'))
df19 = pd.DataFrame.from_records(records)
df19.head()
# Out:
#             id     username  online  \
# 0      skh1344      Skh1344    True
# 1       bibbbu       bibbbu   False
# 2  kasranozari  kasranozari   False
# 3  ghrsalimian  ghrsalimian   False
# 4      rino233      Rino233    True
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 7071, 'rating': 1871, 'rd'...  1600263841080
# 1  {'antichess': {'games': 10, 'rating': 1009, 'r...  1615736696476
# 2  {'blitz': {'games': 121, 'rating': 1088, 'rd':...  1612366272312
# 3  {'chess960': {'games': 3, 'rating': 1359, 'rd'...  1410936763022
# 4  {'chess960': {'games': 19, 'rating': 1302, 'rd...  1600696412363
#
#          seenAt                        playTime language  \
# 0  1.617030e+12     {'total': 3201023, 'tv': 0}    fa-IR
# 1  1.617015e+12       {'total': 61702, 'tv': 0}    en-GB
# 2  1.617019e+12      {'total': 144134, 'tv': 0}    fa-IR
# 3  1.617004e+12  {'total': 5884747, 'tv': 5917}    fa-IR
# ...

# %%
records = map(ujson.loads, open('greek.ndjson',encoding='utf-8'))
df20 = pd.DataFrame.from_records(records)
df20.head()
# Out:
#               id       username  online  \
# 0        joehner        Joehner    True
# 1  zxnxplaychess  ZxnxPlayChess   False
# 2          dah01          dah01    True
# 3    punchxwissi    punchxwissi   False
# 4      bramdroid      Bramdroid    True
#
#                                                perfs      createdAt  \
# 0  {'blitz': {'games': 3, 'rating': 1598, 'rd': 1...  1609784465067
# 1  {'blitz': {'games': 86, 'rating': 1715, 'rd': ...  1615305020621
# 2  {'blitz': {'games': 30, 'rating': 1017, 'rd': ...  1612091143002
# 3  {'blitz': {'games': 2513, 'rating': 1594, 'rd'...  1522861063685
# 4  {'blitz': {'games': 0, 'rating': 1500, 'rd': 5...  1609681837171
#
#           seenAt                       playTime language  \
# 0  1617030332708      {'total': 15278, 'tv': 0}    de-DE
# 1  1617029101237      {'total': 21420, 'tv': 0}    de-DE
# 2  1617028001348      {'total': 20860, 'tv': 0}    de-DE
# 3  1617013270170    {'total': 3000798, 'tv': 0}    de-DE
# ...

# %%
fulldf = df1.append(df2,ignore_index=True,sort=False)
fulldf = fulldf.append(df3,ignore_index=True,sort=False)
fulldf = fulldf.append(df4,ignore_index=True,sort=False)
fulldf = fulldf.append(df5,ignore_index=True,sort=False)
fulldf = fulldf.append(df6,ignore_index=True,sort=False)
fulldf = fulldf.append(df7,ignore_index=True,sort=False)
fulldf = fulldf.append(df8,ignore_index=True,sort=False)
fulldf = fulldf.append(df9,ignore_index=True,sort=False)
fulldf = fulldf.append(df10,ignore_index=True,sort=False)
fulldf = fulldf.append(df11,ignore_index=True,sort=False)
fulldf = fulldf.append(df12,ignore_index=True,sort=False)
fulldf = fulldf.append(df13,ignore_index=True,sort=False)
fulldf = fulldf.append(df14,ignore_index=True,sort=False)
fulldf = fulldf.append(df15,ignore_index=True,sort=False)
fulldf = fulldf.append(df16,ignore_index=True,sort=False)
fulldf = fulldf.append(df17,ignore_index=True,sort=False)
fulldf = fulldf.append(df18,ignore_index=True,sort=False)
fulldf = fulldf.append(df19,ignore_index=True,sort=False)
fulldf = fulldf.append(df20,ignore_index=True,sort=False)

# %%
fulldf
# Out:
#                    id       username  online  \
# 0          vay_vision     Vay_Vision   False
# 1        ian_fidelino   Ian_fidelino   False
# 2       bltsandwich64  bltsandwich64   False
# 3           rchoi2010      rchoi2010   False
# 4          furyempire     FuryEmpire   False
# ...               ...            ...     ...
# 304812       schachlp       schachlp   False
# 304813   waschbaer231   Waschbaer231   False
# 304814       jewelz83       jewelz83   False
# 304815    klonkrieger    Klonkrieger   False
# 304816    thebiggreek    TheBigGreek    True
#
#                                                     perfs      createdAt  \
# 0       {'blitz': {'games': 2087, 'rating': 1785, 'rd'...  1588244909571
# 1       {'blitz': {'games': 1282, 'rating': 2297, 'rd'...  1589001550345
# 2       {'blitz': {'games': 92, 'rating': 1439, 'rd': ...  1596664263279
# 3       {'blitz': {'games': 2, 'rating': 1145, 'rd': 2...  1616966305205
# ...

# %%
len(fulldf['id'].unique())
# Out:
# 205126

# %%
df_nodup = fulldf.drop_duplicates(subset=['id'])
df_nodup
# Out:
#                    id       username  online  \
# 0          vay_vision     Vay_Vision   False
# 1        ian_fidelino   Ian_fidelino   False
# 2       bltsandwich64  bltsandwich64   False
# 3           rchoi2010      rchoi2010   False
# 4          furyempire     FuryEmpire   False
# ...               ...            ...     ...
# 304811     dustin1304     Dustin1304   False
# 304813   waschbaer231   Waschbaer231   False
# 304814       jewelz83       jewelz83   False
# 304815    klonkrieger    Klonkrieger   False
# 304816    thebiggreek    TheBigGreek    True
#
#                                                     perfs      createdAt  \
# 0       {'blitz': {'games': 2087, 'rating': 1785, 'rd'...  1588244909571
# 1       {'blitz': {'games': 1282, 'rating': 2297, 'rd'...  1589001550345
# 2       {'blitz': {'games': 92, 'rating': 1439, 'rd': ...  1596664263279
# 3       {'blitz': {'games': 2, 'rating': 1145, 'rd': 2...  1616966305205
# ...

# %%
df_nodup.to_csv('allteams.csv')
