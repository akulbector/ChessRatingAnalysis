# %%
import pandas as pd
import lichess.api

# %%
dfrosen = pd.read_csv('LichessTeams\ericrosen.csv')
dfrosen
# Out:
#                          id              username  online  perfs_blitz_games  \
# 0            jude86_nilanga        Jude86_Nilanga   False                 13
# 1                notbatman0            NotBatman0   False                  7
# 2                  bhavvesh              bhavvesh   False                  0
# 3                etmarkwell            etmarkwell   False                779
# 4      imdoinjjackswmeatout  imdoinjjackswmeatout   False                 58
# ...                     ...                   ...     ...                ...
# 12291             lilypants             lilypants   False               1702
# 12292                  cj58                  CJ58   False               3048
# 12293        russianeagle96        RussianEagle96   False               4419
# 12294          pikachu88888          Pikachu88888    True               1748
# 12295             ericrosen             EricRosen   False               3790
#
# ...

# %%
dfrosen['id'][2]
# Out:
# 'bhavvesh'

# %%
for i in range(len(dfrosen)):
    user = lichess.api.user(dfrosen['id'][i])
    print(dfrosen['id'][i])
